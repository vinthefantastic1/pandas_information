# %%
import pandas as pd

df = pd.read_html('https://en.wikipedia.org/wiki/List_of_historically_black_colleges_and_universities')
# what's in the first data frame?
df[0]
# Out:
#                                                     0
# 0                                 Part of a series on
# 1                                   African Americans
# 2   History Periods Timeline Atlantic slave trade ...
# 3                                             Periods
# 4   Timeline Atlantic slave trade Slavery in the c...
# ..                                                ...
# 66  Race and ethnicity in the United States Census...
# 67                   Stereotypes and media depictions
# 68  Hollywood Minstrel show Blackface Magical Negr...
# 69                United States portal Category Index
# 70                                                vte
#
# [71 rows x 1 columns]

# %%
# Randomly choose another df
df[6]
# Out:
#                                                    0
# 0                              Negro league baseball
# 1              Athletic associations and conferences
# 2  Central (CIAA) Southern (SIAC) Mid-Eastern (ME...

# %%
# How many total df?
len(df)
# Out:
# 14

# %%
for i in df:
    print(i)
# Out:
#                                                     0
# 0                                 Part of a series on
# 1                                   African Americans
# 2   History Periods Timeline Atlantic slave trade ...
# 3                                             Periods
# 4   Timeline Atlantic slave trade Slavery in the c...
# ..                                                ...
# 66  Race and ethnicity in the United States Census...
# 67                   Stereotypes and media depictions
# 68  Hollywood Minstrel show Blackface Magical Negr...
# 69                United States portal Category Index
# 70                                                vte
#
# [71 rows x 1 columns]
#                                              Periods
# 0  Timeline Atlantic slave trade Slavery in the c...
# 1                                            Aspects
# 2  Agriculture history Business history Black Bel...
# 3                                         Migrations
# ...

# %%
# The one we want is 11
df[11]
# Out:
#                              School           City State/Territory  Founded  \
# 0            Alabama A&M University         Normal         Alabama     1875
# 1          Alabama State University     Montgomery         Alabama     1867
# 2           Albany State University         Albany         Georgia     1903
# 3           Alcorn State University         Lorman     Mississippi     1871
# 4                  Allen University       Columbia  South Carolina     1870
# ..                              ...            ...             ...      ...
# 100  West Virginia State University      Institute   West Virginia     1891
# 101          Wilberforce University    Wilberforce            Ohio     1856
# 102                   Wiley College       Marshall           Texas     1873
# 103  Winston-Salem State University  Winston-Salem  North Carolina     1892
# 104  Xavier University of Louisiana    New Orleans       Louisiana     1915
#
#         Type               Religious Affiliation  \
# ...

# %%
HBCU_closed=df[12]
HBCU_closed
# Out:
#                                  School  \
# 0                         Avery College
# 1                        Bishop College
# 2   Booker T. Washington Junior College
# 3                J. P. Campbell College
# 4                 Carver Junior College
# 5        Collier-Blocker Junior College
# 6            Concordia College, Alabama
# 7                  Daniel Payne College
# 8                    Friendship College
# 9               George R. Smith College
# 10                 Gibbs Junior College
# 11                    Guadalupe College
# 12               Hampton Junior College
# 13               Jackson Junior College
# 14               Johnson Junior College
# 15                     Kittrell College
# 16                    Leland University
# 17            Lewis College of Business
# 18               Lincoln Junior College
# 19                  Mary Holmes College
# 20       Mississippi Industrial College
# 21                   Morristown College
# ...

# %%
df_HBCU=df[11]

# %%
# Which state has the most HBCU's
df_HBCU["State/Territory"].value_counts()
# Out:
# Alabama                         14
# North Carolina                  11
# Georgia                         10
# Texas                            9
# South Carolina                   8
# Mississippi                      7
# Tennessee                        7
# Louisiana                        6
# Virginia                         5
# Florida                          4
# Maryland                         4
# Arkansas                         4
# Ohio                             3
# West Virginia                    2
# Pennsylvania                     2
# District of Columbia             2
# Kentucky                         2
# Missouri                         2
# Oklahoma                         1
# United States Virgin Islands     1
# Delaware                         1
# Name: State/Territory, dtype: int64

# %%
# Counter number of closed HBCU's
HBCU_closed["State"].value_counts()
# Out:
# Florida           12
# Mississippi        7
# Alabama            2
# Tennessee          2
# Texas              2
# Kansas             1
# Pennsylvania       1
# Louisiana          1
# Michigan           1
# West Virginia      1
# Georgia            1
# North Carolina     1
# Virginia           1
# Missouri           1
# South Carolina     1
# Name: State, dtype: int64

# %%
HBCU_closed
# Out:
#                                  School  \
# 0                         Avery College
# 1                        Bishop College
# 2   Booker T. Washington Junior College
# 3                J. P. Campbell College
# 4                 Carver Junior College
# 5        Collier-Blocker Junior College
# 6            Concordia College, Alabama
# 7                  Daniel Payne College
# 8                    Friendship College
# 9               George R. Smith College
# 10                 Gibbs Junior College
# 11                    Guadalupe College
# 12               Hampton Junior College
# 13               Jackson Junior College
# 14               Johnson Junior College
# 15                     Kittrell College
# 16                    Leland University
# 17            Lewis College of Business
# 18               Lincoln Junior College
# 19                  Mary Holmes College
# 20       Mississippi Industrial College
# 21                   Morristown College
# ...

# %%
# Increase the number of rows to display
pd.set_option('display.max_rows', None)
df_HBCU.sort_values(['Founded'])
# Out:
#                                                 School  \
# 16                  Cheyney University of Pennsylvania
# 25              University of the District of Columbia
# 51                                  Lincoln University
# 101                             Wilberforce University
# 69                          Payne Theological Seminary
# 36                       Harris-Stowe State University
# 50                                LeMoyne-Owen College
# 18                            Clark Atlanta University
# 97                           Virginia Union University
# 75                                     Shaw University
# 14                              Bowie State University
# 29                                     Fisk University
# 26                               Edward Waters College
# 72                                        Rust College
# 52                      Lincoln University of Missouri
# 38                                   Howard University
# ...

# %%
# Which ones are named "Morehouse"
df_HBCU[df_HBCU["School"].str.contains("Morehouse")]
# Out:
#                           School     City State/Territory  Founded     Type  \
# 58             Morehouse College  Atlanta         Georgia     1867  Private
# 59  Morehouse School of Medicine  Atlanta         Georgia     1975  Private
#
#                                 Religious Affiliation  \
# 58  Originally: American Baptist Home Mission Society
# 59                                                NaN
#
#                                    Comment Regionally accredited[3]
# 58          Founded as "Augusta Institute"                      Yes
# 59  Founded as a part of Morehouse College                      Yes

# %%
# show a few off the top. Could also use df_HBCU.head()
df_HBCU[0:3]
# Out:
#                      School        City State/Territory  Founded    Type  \
# 0    Alabama A&M University      Normal         Alabama     1875  Public
# 1  Alabama State University  Montgomery         Alabama     1867  Public
# 2   Albany State University      Albany         Georgia     1903  Public
#
#   Religious Affiliation                                            Comment  \
# 0                   NaN   Founded as "Colored Normal School at Huntsville"
# 1                   NaN       Founded as "Lincoln Normal School of Marion"
# 2                   NaN  Founded as "Albany Bible and Manual Training I...
#
#   Regionally accredited[3]
# 0                      Yes
# 1                      Yes
# 2                      Yes

# %%
df_HBCU.head()
# Out:
#                      School        City State/Territory  Founded     Type  \
# 0    Alabama A&M University      Normal         Alabama     1875   Public
# 1  Alabama State University  Montgomery         Alabama     1867   Public
# 2   Albany State University      Albany         Georgia     1903   Public
# 3   Alcorn State University      Lorman     Mississippi     1871   Public
# 4          Allen University    Columbia  South Carolina     1870  Private
#
#          Religious Affiliation  \
# 0                          NaN
# 1                          NaN
# 2                          NaN
# 3                          NaN
# 4  African Methodist Episcopal
#
#                                              Comment Regionally accredited[3]
# 0   Founded as "Colored Normal School at Huntsville"                      Yes
# 1       Founded as "Lincoln Normal School of Marion"                      Yes
# 2  Founded as "Albany Bible and Manual Training I...                      Yes
# ...

# %%
xx=df_HBCU.loc[9:,"School":"State/Territory"]

# %%
type(xx)
# Out:
# pandas.core.frame.DataFrame

# %%
# show the names starting with row 9
df_HBCU.loc[9:,"School":"School"]
# Out:
#                                                 School
# 9                                     Benedict College
# 10                                     Bennett College
# 11                          Bethune-Cookman University
# 12                      Bishop State Community College
# 13                             Bluefield State College
# 14                              Bowie State University
# 15                            Central State University
# 16                  Cheyney University of Pennsylvania
# 17                                  Claflin University
# 18                            Clark Atlanta University
# 19                                     Clinton College
# 20                           Coahoma Community College
# 21                             Coppin State University
# 22                           Delaware State University
# 23                           Denmark Technical College
# 24                                  Dillard University
# ...

# %%
# Just show the one row
df_HBCU.loc[9:9]
# Out:
#              School      City State/Territory  Founded     Type  \
# 9  Benedict College  Columbia  South Carolina     1870  Private
#
#            Religious Affiliation                          Comment  \
# 9  American Baptist Churches USA  Founded as "Benedict Institute"
#
#   Regionally accredited[3]
# 9                      Yes

# %%
# Show everything for row 9 starting with "State/Territory"
df_HBCU.loc[9:9,"State/Territory":]
# Out:
#   State/Territory  Founded     Type          Religious Affiliation  \
# 9  South Carolina     1870  Private  American Baptist Churches USA
#
#                            Comment Regionally accredited[3]
# 9  Founded as "Benedict Institute"                      Yes

# %%
df_HBCU.iloc[9:10,0:1]
# Out:
#              School
# 9  Benedict College

# %%
df_HBCU.iloc[9:11,0:2]
# Out:
#               School        City
# 9   Benedict College    Columbia
# 10   Bennett College  Greensboro

# %%
# Let's find all the HBCU's in Greensboro
ss="Greensboro"

# %%
df_HBCU[df_HBCU["State/Territory"].str.contains(ss) | df_HBCU["City"].str.contains(ss)]
# Out:
#                                                School        City  \
# 10                                    Bennett College  Greensboro
# 64  North Carolina Agricultural & Technical State ...  Greensboro
#
#    State/Territory  Founded     Type    Religious Affiliation  \
# 10  North Carolina     1873  Private  United Methodist Church
# 64  North Carolina     1891   Public                      NaN
#
#                                               Comment Regionally accredited[3]
# 10                      Founded as "Bennett Seminary"                      Yes
# 64  Founded as "The Agricultural & Mechanical Coll...                      Yes

# %%
df_HBCU[["School","State/Territory","Founded"]]
# Out:
# School                                                    State/Territory               Founded
# Xavier University of Louisiana                            Louisiana                     1915       1
# Livingstone College                                       North Carolina                1879       1
# Fisk University                                           Tennessee                     1866       1
# Florida A&M University                                    Florida                       1887       1
# Florida Memorial University                               Florida                       1879       1
# Fort Valley State University                              Georgia                       1895       1
# Gadsden State Community College                           Alabama                       1925       1
# Grambling State University                                Louisiana                     1901       1
# ...

# %%
# Which city has the most HBCU's
pd.set_option('display.max_rows', 10)
df_HBCU["City"].value_counts()
# Out:
# Atlanta        6
# Nashville      4
# Wilberforce    3
# New Orleans    3
# Baltimore      2
#               ..
# Utica          1
# Austin         1
# Institute      1
# Langston       1
# Tyler          1
# Name: City, Length: 81, dtype: int64

# %%
# Which state has the most HBCU's
df_HBCU[["State/Territory"]].value_counts()
# Out:
# State/Territory
# Alabama                         14
# North Carolina                  11
# Georgia                         10
# Texas                            9
# South Carolina                   8
#                                 ..
# Pennsylvania                     2
# Missouri                         2
# Oklahoma                         1
# Delaware                         1
# United States Virgin Islands     1
# Length: 21, dtype: int64

# %%
df_HBCU[df_HBCU["State/Territory"]=="Alabama"]
# Out:
#                                  School              City State/Territory  \
# 0                Alabama A&M University            Normal         Alabama
# 1              Alabama State University        Montgomery         Alabama
# 12       Bishop State Community College            Mobile         Alabama
# 33      Gadsden State Community College           Gadsden         Alabama
# 41  J. F. Drake State Technical College        Huntsville         Alabama
# ..                                  ...               ...             ...
# 77      Shelton State Community College        Tuscaloosa         Alabama
# 87                     Stillman College        Tuscaloosa         Alabama
# 88                    Talladega College  Talladega County         Alabama
# 93     Trenholm State Technical College        Montgomery         Alabama
# 94                  Tuskegee University          Tuskegee         Alabama
#
#     Founded     Type    Religious Affiliation  \
# ...

# %%
df_HBCU[["School","State/Territory","Founded"]]
# Out:
#                              School State/Territory  Founded
# 0            Alabama A&M University         Alabama     1875
# 1          Alabama State University         Alabama     1867
# 2           Albany State University         Georgia     1903
# 3           Alcorn State University     Mississippi     1871
# 4                  Allen University  South Carolina     1870
# ..                              ...             ...      ...
# 100  West Virginia State University   West Virginia     1891
# 101          Wilberforce University            Ohio     1856
# 102                   Wiley College           Texas     1873
# 103  Winston-Salem State University  North Carolina     1892
# 104  Xavier University of Louisiana       Louisiana     1915
#
# [105 rows x 3 columns]

# %%
# for HBCU's in Alabama, show the HBCU school name and city 
pd.set_option('display.max_rows', None)
df3 = df_HBCU.loc[df_HBCU["State/Territory"] == "Alabama", ["School","City"]]
df3
# Out:
#                                  School              City
# 0                Alabama A&M University            Normal
# 1              Alabama State University        Montgomery
# 12       Bishop State Community College            Mobile
# 33      Gadsden State Community College           Gadsden
# 41  J. F. Drake State Technical College        Huntsville
# 49       Lawson State Community College          Bessemer
# 56                        Miles College         Fairfield
# 66                   Oakwood University        Huntsville
# 74                     Selma University             Selma
# 77      Shelton State Community College        Tuscaloosa
# 87                     Stillman College        Tuscaloosa
# 88                    Talladega College  Talladega County
# 93     Trenholm State Technical College        Montgomery
# 94                  Tuskegee University          Tuskegee
